# %% [markdown]
# # 31. Factorials
#
# ## Recursive functions
#
# [Learn Python with Jupyter](https://learnpythonwithjupyter.com/) by [Serena Bonaretti](https://sbonaretti.github.io/)
# Narrative license: [CC BY-NC-SA](https://creativecommons.org/licenses/by-nc-sa/2.0/). Code license: [GNU-GPL v3](https://www.gnu.org/licenses/gpl-3.0.en.html)
#
# ---

# %% [markdown]
# - Write a function that calculates the factorial of a given integer using a for loop:

# %%
def factorial_for(n):
    """Calculates the factorial of a given integer using a for loop

    Parameters
    ----------
    n : integer
        The input integer 

    Returns
    -------
    factorial : integer 
        The factorial of the input integer
    """

    # initialize the result to one
    factorial = 1

    # for each integer between 2 and the input integer
    for i in range(2, n+1):
        # multiply the current result for the current integer 
        factorial *= i

    # return the result
    return factorial

# call the function
fact = factorial_for(4)
print(fact)

# %% [markdown]
# - Compare the previous iterative function with the following recursive function:

# %%
def factorial_rec(n):
    """Calculates the factorial of a given integer using recursion

    Parameters
    ----------
    n : integer
        The input integer 

    Returns
    -------
    integer 
        The factorial of the input integer
    """
  
    # if n is greater than 1
    if n > 1: 
        # execute the recursion
        return factorial_rec(n-1) * n
    # otherwise
    else: 
        # return 1
        return 1 

# call the function
fact = factorial_rec(4)
print(fact)

# %% [markdown]
# # Practice

# %%
# fibonacci recursive
def fibonacci(n):
    if(n == 0): 
        print(0)
        return 0
    else:
        x = fibonacci(n-1) + n
        print(x)
        return x
    
fibonacci(0)
print()

fibonacci(1)
print()

fibonacci(5)
print()

# %%
def fibonacci_rec(n, seq):
    if n < 1:
        return
    else:
        fibonacci_rec(n-1,seq)
        seq.append(n + seq[-1])
        
    
def fibonacci_list(n):
    seq = [0]
    fibonacci_rec(n, seq)
    return seq

seq = fibonacci_list(0)
print(seq)

seq = fibonacci_list(1)
print(seq)

seq = fibonacci_list(5)
print(seq)

seq = fibonacci_list(10)
print(seq)

# %%
def fibonacci_rec(i, n, seq):
    if n < i:
        return
    else:
        seq.append(i + seq[-1])
        fibonacci_rec(i+1, n, seq)
    
def fibonacci_list(n):
    seq = [0]
    fibonacci_rec(1, n, seq)
    return seq


seq = fibonacci_list(0)
print(seq)

seq = fibonacci_list(1)
print(seq)

seq = fibonacci_list(5)
print(seq)

seq = fibonacci_list(10)
print(seq)
